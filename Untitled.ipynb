# %%
import astropy.io.fits as fits
import zipfile
import os
import io
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
archive = zipfile.ZipFile('TAL250K.zip', 'r')
for img_name in archive.namelist():
    img_bytes = archive.read(imgname)
    img_stream = io.BytesIO(img_bytes)
    hdu_list = fits.open(img_stream)
    print(hdu.info())
    hdu.readall()
    image_data = hdu_list[0].data
    plt.imshow(image_data, cmap='gray')
    plt.colorbar()
    break
# Out:
# Filename: <class '_io.BytesIO'>
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      56   (1160, 880)   int16 (rescales to uint16)
# None
