# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import Input, Model
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.layers import *
from tensorflow.keras.metrics import *
from tensorflow.keras.metrics import Metric
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.regularizers import l2

# %%
# Подготовка данных для модели
y_labels = pd.read_csv('y_labels_100thsnd_withoutscaler.csv')

cnn_arrays = np.load('shuffled_combined_100thsnd_withoutscaler.npz')
X_ts = cnn_arrays['X']
ids_ts = cnn_arrays['ids']

# %%
# Выберем звезду с известным периодом для примера
target_id = 317827720286      
index = np.where(ids_ts == target_id)[0][0]
print(f"Индекс элемента: {index}")
# Out:
# Индекс элемента: 49363

# %%
y_labels.iloc[49363]
# Out:
# asas_sn_id          317827720286
# main_class             PULSATING
# variability_type            DCEP
# Name: 49363, dtype: object

# %%
# Пример звезды с известным периодом (сырая кривая блеска и фазово-сложенная)
i = 49363
sample = X_ts[i]
mjd = sample[:, 2]
mag = sample[:, 0]

# Известный период
P = 23.054000  

# Фазовая кривая
phase = (mjd % P) / P

# Отсекаем паддинг
mask = mjd != 0
mjd = mjd[mask]
mag = mag[mask]
phase = phase[mask]

fig, axs = plt.subplots(2, 1, figsize=(10, 6))

axs[0].scatter(mjd, mag, color="#6451A2", s=10)
axs[0].set_title('"Сырая" кривая блеска')
axs[0].invert_yaxis()
axs[0].set_xlabel('MJD')
axs[0].set_ylabel('Звездная величина (mag)')
axs[0].grid(True)

axs[1].scatter(phase, mag, color="#E16B7B", s=10)
axs[1].set_title('Фазово-сложенная кривая блеска')
axs[1].invert_yaxis()
axs[1].set_xlabel('Фаза')
axs[1].set_ylabel('Звездная величина (mag)')
axs[1].grid(True)


plt.tight_layout()
plt.show()

# %%
# Стратифицированное разделение с сохранением индексов
X_train, X_val, y_train, y_val, idx_train, idx_val = train_test_split(
    X_ts,
    y_labels['main_class'].values,
    ids_ts,
    test_size=0.2,
    stratify=y_labels['main_class'],
    random_state=42
)

# %%
# Вычисление весов классов
class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(y_labels['main_class']),
    y=y_labels['main_class']
)

# Преобразование в словарь
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}
class_weight_dict
# Out:
# {0: 0.7715051266478511,
#  1: 5.622285863056495,
#  2: 0.4320595414349166,
#  3: 1.0884677419354838,
#  4: 3.4158810503005377}

# %%
unique, counts = np.unique(y_train, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [['ECLIPSING' 22393]
#  ['ERUPTIVE' 3073]
#  ['PULSATING' 39985]
#  ['ROTATING' 15872]
#  ['cataclysmic' 5057]]

# %%
# Применение SMOTE
smote = SMOTE(
    sampling_strategy={
        'ECLIPSING': 22393,
        'ERUPTIVE': 10000,
        'PULSATING': 39985,
        'ROTATING': 20000,
        'cataclysmic': 10000
    },
    random_state=42,
    k_neighbors=3
)

# Преобразование данных для SMOTE
n_samples, timesteps, features = X_train.shape
X_train_flat = X_train.reshape(n_samples, -1)
X_train_resampled_flat, y_train_resampled = smote.fit_resample(X_train_flat, y_train)

# Восстановление 3D структуры
X_train_resampled = X_train_resampled_flat.reshape(-1, timesteps, features)

# Генерация ID для синтетических данных
original_ids_train = ids_ts[idx_train]
n_synthetic = len(y_train_resampled) - len(y_train)
synthetic_ids = np.array([f'synthetic_{i}' for i in range(n_synthetic)])
ids_train_resampled = np.concatenate([original_ids_train, synthetic_ids])

# %%
# Вычисление весов классов после SMOTE
unique, counts = np.unique(y_train_resampled, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [['ECLIPSING' 22393]
#  ['ERUPTIVE' 10000]
#  ['PULSATING' 39985]
#  ['ROTATING' 20000]
#  ['cataclysmic' 10000]]

# %%
# Создаем DataFrame с метками
df_before = pd.DataFrame({'Класс': y_train, 'Источник': 'До SMOTE'})
df_after = pd.DataFrame({'Класс': y_train_resampled, 'Источник': 'После SMOTE'})
df_combined = pd.concat([df_before, df_after])

# Словарь для перевода меток
class_labels_ru = {
    "ECLIPSING": 'Затменные',
    "ERUPTIVE": 'Эруптивные',
    "PULSATING": 'Пульсирующие',
    "ROTATING": 'Вращающиеся',
    "cataclysmic": 'Катаклизмические'
}
class_order = list(class_labels_ru.values())
df_combined['Класс'] = df_combined['Класс'].map(class_labels_ru)

custom_palette = ["#8DD0ED", "#D1E0AF"]

plt.figure(figsize=(12, 6))
sns.countplot(
    data=df_combined, 
    x='Класс', 
    hue='Источник',
    palette=custom_palette,
    edgecolor='black',
    linewidth=0.5,
    order=class_order  
)

plt.title('Классы до и после SMOTE', fontsize=14, pad=15)
plt.xlabel('Класс', fontsize=12)
plt.ylabel('Количество, единиц', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

legend = plt.legend(
    title='Источник', 
    title_fontsize=12,
    fontsize=12,
    frameon=True,
    framealpha=0.9
)
legend.get_frame().set_edgecolor('gray')

plt.tight_layout()
plt.show()

# %%
def scale_dataset(data):
    """Масштабируем данные с сохранением паддинга для каждого образца отдельно"""
    scaled_data = np.empty_like(data)
    
    for i in range(data.shape[0]):
        # Копируем признаки
        mag = data[i, :, 0].copy()
        mag_err = data[i, :, 1].copy()
        mjd = data[i, :, 2].copy()
        
        # Определяем границу паддинга по MJD
        non_zero_mask = mjd != 0.0
        valid_length = np.sum(non_zero_mask)
        
        if valid_length > 0:
            # Масштабируем каждый признак отдельно
            for ch, feature in enumerate([mag, mag_err, mjd]):
                scaler = StandardScaler()
                scaled_part = scaler.fit_transform(feature[:valid_length].reshape(-1, 1)).flatten()
                feature[:valid_length] = scaled_part
        
        # Сохраняем масштабированные данные
        scaled_data[i, :, 0] = mag
        scaled_data[i, :, 1] = mag_err
        scaled_data[i, :, 2] = mjd
    
    return scaled_data

# %%
# Применяем масштабирование для модели без SMOTE
X_train_scaled = scale_dataset(X_train)
X_val_scaled = scale_dataset(X_val)

# %%
# Кодирование целевых переменных для модели без SMOTE
ohe_main = OneHotEncoder(sparse_output=False)
y_train_onehot = ohe_main.fit_transform(pd.DataFrame(y_train, columns=['main_class']))
y_val_onehot = ohe_main.transform(pd.DataFrame(y_val, columns=['main_class']))

# %%
# Применяем масштабирование для модели со SMOTE
X_train_scaled = scale_dataset(X_train_resampled)
X_val_scaled = scale_dataset(X_val)

# %%
# Кодирование целевых переменных для модели со SMOTE
ohe_main = OneHotEncoder(sparse_output=False)
y_train_resampled_onehot = ohe_main.fit_transform(pd.DataFrame(y_train_resampled, columns=['main_class']))
y_val_onehot = ohe_main.transform(pd.DataFrame(y_val, columns=['main_class']))

# %%
# Пример до и после масштабирования данных
i = 44389
original = X_train[i]
scaled = scale_dataset(X_train[[i]])[0]

fig, axs = plt.subplots(2, 1, figsize=(10, 6), sharex=True)

axs[0].plot(original[:, 2], original[:, 0], label='До масштабирования', color='blue')
axs[0].set_title('Сырая кривая блеска')
axs[0].set_ylabel('Яркость (mag)')
axs[0].grid(True)

axs[1].plot(scaled[:, 2], scaled[:, 0], label='После масштабирования', color='green')
axs[1].set_title('Масштабированная кривая')
axs[1].set_xlabel('MJD')
axs[1].set_ylabel('Яркость (mag)')
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
n_samples, timesteps, features = X_train.shape

# %%
# Callbacks
from tensorflow.keras.callbacks import ModelCheckpoint
# Коллбэк для сохранения F1
checkpoint_f1 = ModelCheckpoint(
    filepath='/content/drive/MyDrive/best_f1.keras',
    monitor='val_f1_score',
    mode='max',
    save_best_only=True,
    verbose=1
)

# Коллбэк для сохранения val_loss
checkpoint_loss = ModelCheckpoint(
    filepath='/content/drive/MyDrive/best_loss.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    TensorBoard(log_dir='./logs'),
    checkpoint_f1,
    checkpoint_loss
]

# %%
def build_model(input_shape, num_classes):
    # Вход для временных рядов
    ts_input = Input(shape=input_shape, name='ts_input')

    # CNN-ветвь
    x = Conv1D(128, 7, padding='same')(ts_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    x = Conv1D(256, 7, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    x = MaxPooling1D(2)(x)

    # Сохраняем тензор для residual connection
    residual = x
   
    x = MultiHeadAttention(num_heads=8, key_dim=32)(x, x)
    x = LayerNormalization(epsilon=1e-6)(x + residual)

    # LSTM блок
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = GlobalAveragePooling1D()(x)

    # Классификатор
    output = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
    output = Dropout(0.5)(output)
    output = Dense(num_classes, activation='softmax')(output)

    return Model(inputs=ts_input, outputs=output)

# %%
# Компиляция модели
model = build_model(
    input_shape=(timesteps, features),
    num_classes=len(ohe_main.categories_[0])
)
model.compile(
    optimizer=Nadam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=[F1Score(average='macro')]
)

# %% [markdown]
# Обучение модели без SMOTE

# %%
# Обучение модели
history = model.fit(
    X_train_scaled,
    y_train_onehot,
    epochs=50,
    batch_size=128,
    #class_weight=class_weight_dict,
    validation_data=([X_val_scaled], y_val_onehot),
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.3612 - loss: 1.6479
# Epoch 1: val_f1_score did not improve from 0.50593
#
# Epoch 1: val_loss did not improve from 0.97498
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 104s 159ms/step - f1_score: 0.3613 - loss: 1.6472 - val_f1_score: 0.4746 - val_loss: 1.0143
# Epoch 2/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.4971 - loss: 0.9963
# Epoch 2: val_f1_score improved from 0.50593 to 0.51167, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 2: val_loss improved from 0.97498 to 0.96929, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 145s 165ms/step - f1_score: 0.4971 - loss: 0.9963 - val_f1_score: 0.5117 - val_loss: 0.9693
# Epoch 3/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.5152 - loss: 0.9675
# Epoch 3: val_f1_score improved from 0.51167 to 0.53118, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 3: val_loss improved from 0.96929 to 0.93618, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 165ms/step - f1_score: 0.5152 - loss: 0.9675 - val_f1_score: 0.5312 - val_loss: 0.9362
# Epoch 4/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.5308 - loss: 0.9377
# Epoch 4: val_f1_score improved from 0.53118 to 0.53477, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 4: val_loss improved from 0.93618 to 0.91764, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 165ms/step - f1_score: 0.5308 - loss: 0.9377 - val_f1_score: 0.5348 - val_loss: 0.9176
# Epoch 5/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.5424 - loss: 0.9206
# Epoch 5: val_f1_score did not improve from 0.53477
#
# Epoch 5: val_loss did not improve from 0.91764
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 138s 158ms/step - f1_score: 0.5424 - loss: 0.9206 - val_f1_score: 0.5206 - val_loss: 0.9407
# Epoch 6/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5528 - loss: 0.9152
# Epoch 6: val_f1_score improved from 0.53477 to 0.55723, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 6: val_loss improved from 0.91764 to 0.90181, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 145s 164ms/step - f1_score: 0.5528 - loss: 0.9152 - val_f1_score: 0.5572 - val_loss: 0.9018
# Epoch 7/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.5372 - loss: 0.9286
# Epoch 7: val_f1_score did not improve from 0.55723
#
# Epoch 7: val_loss did not improve from 0.90181
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 138s 158ms/step - f1_score: 0.5372 - loss: 0.9286 - val_f1_score: 0.5372 - val_loss: 0.9153
# Epoch 8/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.5553 - loss: 0.9030
# Epoch 8: val_f1_score did not improve from 0.55723
#
# Epoch 8: val_loss did not improve from 0.90181
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 158ms/step - f1_score: 0.5553 - loss: 0.9030 - val_f1_score: 0.5400 - val_loss: 0.9138
# Epoch 9/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5723 - loss: 0.8819
# Epoch 9: val_f1_score did not improve from 0.55723
#
# Epoch 9: val_loss improved from 0.90181 to 0.89697, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 94s 158ms/step - f1_score: 0.5722 - loss: 0.8819 - val_f1_score: 0.5527 - val_loss: 0.8970
# Epoch 10/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5643 - loss: 0.8858
# Epoch 10: val_f1_score did not improve from 0.55723
#
# Epoch 10: val_loss improved from 0.89697 to 0.89596, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 98s 164ms/step - f1_score: 0.5643 - loss: 0.8858 - val_f1_score: 0.5562 - val_loss: 0.8960
# Epoch 11/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5736 - loss: 0.8768
# Epoch 11: val_f1_score improved from 0.55723 to 0.56926, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 11: val_loss improved from 0.89596 to 0.89171, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 164ms/step - f1_score: 0.5736 - loss: 0.8767 - val_f1_score: 0.5693 - val_loss: 0.8917
# Epoch 12/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5848 - loss: 0.8618
# Epoch 12: val_f1_score did not improve from 0.56926
#
# Epoch 12: val_loss improved from 0.89171 to 0.87700, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 164ms/step - f1_score: 0.5848 - loss: 0.8618 - val_f1_score: 0.5641 - val_loss: 0.8770
# Epoch 13/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5871 - loss: 0.8632
# Epoch 13: val_f1_score did not improve from 0.56926
#
# Epoch 13: val_loss did not improve from 0.87700
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 163ms/step - f1_score: 0.5871 - loss: 0.8632 - val_f1_score: 0.5502 - val_loss: 0.8973
# Epoch 14/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5867 - loss: 0.8577
# Epoch 14: val_f1_score improved from 0.56926 to 0.57081, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 14: val_loss improved from 0.87700 to 0.87519, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 143s 164ms/step - f1_score: 0.5867 - loss: 0.8577 - val_f1_score: 0.5708 - val_loss: 0.8752
# Epoch 15/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5949 - loss: 0.8495
# Epoch 15: val_f1_score improved from 0.57081 to 0.58467, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 15: val_loss improved from 0.87519 to 0.85862, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 98s 164ms/step - f1_score: 0.5949 - loss: 0.8495 - val_f1_score: 0.5847 - val_loss: 0.8586
# Epoch 16/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.5967 - loss: 0.8457
# Epoch 16: val_f1_score did not improve from 0.58467
#
# Epoch 16: val_loss did not improve from 0.85862
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 97s 163ms/step - f1_score: 0.5967 - loss: 0.8457 - val_f1_score: 0.5702 - val_loss: 0.8674
# Epoch 17/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.6031 - loss: 0.8406
# Epoch 17: val_f1_score did not improve from 0.58467
#
# Epoch 17: val_loss did not improve from 0.85862
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 163ms/step - f1_score: 0.6031 - loss: 0.8406 - val_f1_score: 0.5760 - val_loss: 0.8645
# Epoch 18/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.6027 - loss: 0.8333
# Epoch 18: val_f1_score did not improve from 0.58467
#
# Epoch 18: val_loss did not improve from 0.85862
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 163ms/step - f1_score: 0.6027 - loss: 0.8333 - val_f1_score: 0.5528 - val_loss: 0.8858
# Epoch 19/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.6056 - loss: 0.8309
# Epoch 19: val_f1_score did not improve from 0.58467
#
# Epoch 19: val_loss did not improve from 0.85862
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 139s 158ms/step - f1_score: 0.6056 - loss: 0.8309 - val_f1_score: 0.5834 - val_loss: 0.8640
# Epoch 20/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.6111 - loss: 0.8265
# Epoch 20: val_f1_score improved from 0.58467 to 0.59034, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 20: val_loss improved from 0.85862 to 0.85415, saving model to /content/drive/MyDrive/best_loss.keras
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 146s 165ms/step - f1_score: 0.6111 - loss: 0.8265 - val_f1_score: 0.5903 - val_loss: 0.8541
# Epoch 21/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.6121 - loss: 0.8246
# Epoch 21: val_f1_score did not improve from 0.59034
#
# Epoch 21: val_loss did not improve from 0.85415
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 141s 164ms/step - f1_score: 0.6121 - loss: 0.8246 - val_f1_score: 0.5891 - val_loss: 0.8606
# Epoch 22/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - f1_score: 0.6149 - loss: 0.8191
# Epoch 22: val_f1_score did not improve from 0.59034
#
# Epoch 22: val_loss did not improve from 0.85415
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 138s 158ms/step - f1_score: 0.6149 - loss: 0.8191 - val_f1_score: 0.5746 - val_loss: 0.8608
# Epoch 23/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.6136 - loss: 0.8166
# Epoch 23: val_f1_score did not improve from 0.59034
#
# Epoch 23: val_loss did not improve from 0.85415
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 145s 163ms/step - f1_score: 0.6136 - loss: 0.8166 - val_f1_score: 0.5814 - val_loss: 0.8679
# Epoch 24/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.6140 - loss: 0.8159
# Epoch 24: val_f1_score improved from 0.59034 to 0.59230, saving model to /content/drive/MyDrive/best_f1.keras
#
# Epoch 24: val_loss did not improve from 0.85415
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 163ms/step - f1_score: 0.6140 - loss: 0.8159 - val_f1_score: 0.5923 - val_loss: 0.8668
# Epoch 25/50
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - f1_score: 0.6258 - loss: 0.8070
# Epoch 25: val_f1_score did not improve from 0.59230
#
# Epoch 25: val_loss did not improve from 0.85415
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 142s 163ms/step - f1_score: 0.6257 - loss: 0.8070 - val_f1_score: 0.5867 - val_loss: 0.8696

# %%
# индекс эпохи с max val_f1
best_epoch = np.argmax(history.history['val_f1_score'])

# Метрики лучшей эпохи
best_metrics = {
    'epoch': best_epoch + 1,
    'train_loss': history.history['loss'][best_epoch],
    'val_loss': history.history['val_loss'][best_epoch],
    'train_f1': history.history['f1_score'][best_epoch],
    'val_f1': history.history['val_f1_score'][best_epoch]
}

print(f"Лучшая эпоха: {best_epoch + 1}")
print(f"Train F1: {best_metrics['train_f1']:.4f}")
print(f"Train loss: {best_metrics['train_loss']:.4f}")
print(f"Validation F1: {best_metrics['val_f1']:.4f}")
print(f"Validation Loss: {best_metrics['val_loss']:.4f}")
# Out:
# Лучшая эпоха: 24
# Train F1: 0.6156
# Train loss: 0.8188
# Validation F1: 0.5923
# Validation Loss: 0.8668

# %%
pd.DataFrame(history.history).to_csv('/content/drive/MyDrive/history.csv')

# %%
# Получение предсказаний
y_pred = model.predict(X_val_scaled)
y_pred_classes = np.argmax(y_pred, axis=1)

# Преобразование для истинных меток
y_true_classes = np.argmax(y_val_onehot, axis=1)

# Создание confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Визуализация
plt.figure(figsize=(10, 8))
sns.heatmap(cm,
           annot=True,
           fmt='d',
           cmap='Blues',
           xticklabels=ohe_main.categories_[0],
           yticklabels=ohe_main.categories_[0])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step

# %%
# Генерация отчета
class_names = ohe_main.categories_[0]  
report = classification_report(
    y_true_classes,
    y_pred_classes,
    target_names=class_names,
    digits=4
)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    ECLIPSING     0.6175    0.5922    0.6046      5491
#     ERUPTIVE     0.5941    0.3839    0.4664       732
#    PULSATING     0.6745    0.8299    0.7442      8683
#     ROTATING     0.6239    0.4177    0.5004      3141
#  cataclysmic     0.9141    0.4878    0.6361      1025
#
#     accuracy                         0.6581     19072
#    macro avg     0.6848    0.5423    0.5903     19072
# weighted avg     0.6596    0.6581    0.6474     19072

# %%
plt.figure(figsize=(15, 6))

# График для Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue', linestyle='--')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red', linestyle='-')
plt.title('Loss Dynamics')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# График для F1 Macro
plt.subplot(1, 2, 2)
plt.plot(history.history['f1_score'], label='Train F1 Macro', color='green', linestyle='--')
plt.plot(history.history['val_f1_score'], label='Validation F1 Macro', color='orange', linestyle='-')
plt.title('F1 Macro Dynamics')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Обучение модели со SMOTE

# %%
# Обучение модели
history = model.fit(
    X_train_scaled,
    y_train_resampled_onehot,
    epochs=50,
    batch_size=128,
    #class_weight=class_weight_dict,
    validation_data=(X_val_scaled, y_val_onehot),
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.4814 - loss: 1.6194
# Epoch 1: val_f1_score improved from -inf to 0.50763, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 1: val_loss improved from inf to 1.01563, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 132s 159ms/step - f1_score: 0.4815 - loss: 1.6189 - val_f1_score: 0.5076 - val_loss: 1.0156
# Epoch 2/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.5863 - loss: 1.0116
# Epoch 2: val_f1_score improved from 0.50763 to 0.52397, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 2: val_loss improved from 1.01563 to 0.98623, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 119s 158ms/step - f1_score: 0.5863 - loss: 1.0116 - val_f1_score: 0.5240 - val_loss: 0.9862
# Epoch 3/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6104 - loss: 0.9670
# Epoch 3: val_f1_score did not improve from 0.52397
#
# Epoch 3: val_loss improved from 0.98623 to 0.96630, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 145s 162ms/step - f1_score: 0.6104 - loss: 0.9670 - val_f1_score: 0.5154 - val_loss: 0.9663
# Epoch 4/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6237 - loss: 0.9330
# Epoch 4: val_f1_score improved from 0.52397 to 0.53673, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 4: val_loss did not improve from 0.96630
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 119s 157ms/step - f1_score: 0.6237 - loss: 0.9330 - val_f1_score: 0.5367 - val_loss: 0.9689
# Epoch 5/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - f1_score: 0.6313 - loss: 0.9181
# Epoch 5: val_f1_score improved from 0.53673 to 0.55906, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 5: val_loss improved from 0.96630 to 0.92346, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 139s 153ms/step - f1_score: 0.6313 - loss: 0.9181 - val_f1_score: 0.5591 - val_loss: 0.9235
# Epoch 6/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - f1_score: 0.6426 - loss: 0.9000
# Epoch 6: val_f1_score improved from 0.55906 to 0.55968, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 6: val_loss did not improve from 0.92346
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 145s 157ms/step - f1_score: 0.6426 - loss: 0.9000 - val_f1_score: 0.5597 - val_loss: 0.9542
# Epoch 7/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - f1_score: 0.6478 - loss: 0.8860
# Epoch 7: val_f1_score improved from 0.55968 to 0.56948, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 7: val_loss improved from 0.92346 to 0.91293, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 157ms/step - f1_score: 0.6478 - loss: 0.8860 - val_f1_score: 0.5695 - val_loss: 0.9129
# Epoch 8/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - f1_score: 0.6539 - loss: 0.8781
# Epoch 8: val_f1_score did not improve from 0.56948
#
# Epoch 8: val_loss improved from 0.91293 to 0.91011, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 157ms/step - f1_score: 0.6539 - loss: 0.8781 - val_f1_score: 0.5644 - val_loss: 0.9101
# Epoch 9/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6504 - loss: 0.8779
# Epoch 9: val_f1_score did not improve from 0.56948
#
# Epoch 9: val_loss did not improve from 0.91011
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 145s 161ms/step - f1_score: 0.6504 - loss: 0.8779 - val_f1_score: 0.5611 - val_loss: 0.9285
# Epoch 10/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6602 - loss: 0.8632
# Epoch 10: val_f1_score improved from 0.56948 to 0.57100, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 10: val_loss did not improve from 0.91011
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 139s 158ms/step - f1_score: 0.6602 - loss: 0.8632 - val_f1_score: 0.5710 - val_loss: 0.9126
# Epoch 11/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6699 - loss: 0.8519
# Epoch 11: val_f1_score did not improve from 0.57100
#
# Epoch 11: val_loss did not improve from 0.91011
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 158ms/step - f1_score: 0.6699 - loss: 0.8519 - val_f1_score: 0.5499 - val_loss: 0.9198
# Epoch 12/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6705 - loss: 0.8435
# Epoch 12: val_f1_score did not improve from 0.57100
#
# Epoch 12: val_loss did not improve from 0.91011
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 146s 163ms/step - f1_score: 0.6705 - loss: 0.8435 - val_f1_score: 0.5657 - val_loss: 0.9292
# Epoch 13/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6715 - loss: 0.8371
# Epoch 13: val_f1_score did not improve from 0.57100
#
# Epoch 13: val_loss improved from 0.91011 to 0.90105, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 123s 163ms/step - f1_score: 0.6715 - loss: 0.8371 - val_f1_score: 0.5667 - val_loss: 0.9010
# Epoch 14/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6758 - loss: 0.8311
# Epoch 14: val_f1_score improved from 0.57100 to 0.58282, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 14: val_loss improved from 0.90105 to 0.88763, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 120s 159ms/step - f1_score: 0.6758 - loss: 0.8311 - val_f1_score: 0.5828 - val_loss: 0.8876
# Epoch 15/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6817 - loss: 0.8217
# Epoch 15: val_f1_score did not improve from 0.58282
#
# Epoch 15: val_loss did not improve from 0.88763
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 122s 162ms/step - f1_score: 0.6817 - loss: 0.8217 - val_f1_score: 0.5633 - val_loss: 0.9426
# Epoch 16/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6797 - loss: 0.8184
# Epoch 16: val_f1_score did not improve from 0.58282
#
# Epoch 16: val_loss improved from 0.88763 to 0.88732, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 139s 158ms/step - f1_score: 0.6797 - loss: 0.8184 - val_f1_score: 0.5731 - val_loss: 0.8873
# Epoch 17/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6833 - loss: 0.8177
# Epoch 17: val_f1_score improved from 0.58282 to 0.58443, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 17: val_loss improved from 0.88732 to 0.88588, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 158ms/step - f1_score: 0.6833 - loss: 0.8176 - val_f1_score: 0.5844 - val_loss: 0.8859
# Epoch 18/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6850 - loss: 0.8143
# Epoch 18: val_f1_score did not improve from 0.58443
#
# Epoch 18: val_loss did not improve from 0.88588
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 158ms/step - f1_score: 0.6850 - loss: 0.8143 - val_f1_score: 0.5812 - val_loss: 0.8929
# Epoch 19/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6902 - loss: 0.8003
# Epoch 19: val_f1_score did not improve from 0.58443
#
# Epoch 19: val_loss did not improve from 0.88588
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 122s 162ms/step - f1_score: 0.6902 - loss: 0.8003 - val_f1_score: 0.5733 - val_loss: 0.9252
# Epoch 20/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6918 - loss: 0.7936
# Epoch 20: val_f1_score did not improve from 0.58443
#
# Epoch 20: val_loss did not improve from 0.88588
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 139s 158ms/step - f1_score: 0.6918 - loss: 0.7937 - val_f1_score: 0.5626 - val_loss: 0.9143
# Epoch 21/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6684 - loss: 0.8408
# Epoch 21: val_f1_score did not improve from 0.58443
#
# Epoch 21: val_loss improved from 0.88588 to 0.87871, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 145s 162ms/step - f1_score: 0.6684 - loss: 0.8407 - val_f1_score: 0.5836 - val_loss: 0.8787
# Epoch 22/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.6964 - loss: 0.7879
# Epoch 22: val_f1_score did not improve from 0.58443
#
# Epoch 22: val_loss did not improve from 0.87871
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 138s 158ms/step - f1_score: 0.6964 - loss: 0.7879 - val_f1_score: 0.5737 - val_loss: 0.8953
# Epoch 23/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6972 - loss: 0.7869
# Epoch 23: val_f1_score improved from 0.58443 to 0.58520, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 23: val_loss did not improve from 0.87871
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 145s 162ms/step - f1_score: 0.6972 - loss: 0.7870 - val_f1_score: 0.5852 - val_loss: 0.8848
# Epoch 24/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.6982 - loss: 0.7852
# Epoch 24: val_f1_score did not improve from 0.58520
#
# Epoch 24: val_loss did not improve from 0.87871
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 162ms/step - f1_score: 0.6982 - loss: 0.7852 - val_f1_score: 0.5813 - val_loss: 0.8890
# Epoch 25/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.7016 - loss: 0.7796
# Epoch 25: val_f1_score did not improve from 0.58520
#
# Epoch 25: val_loss did not improve from 0.87871
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 123s 162ms/step - f1_score: 0.7016 - loss: 0.7796 - val_f1_score: 0.5848 - val_loss: 0.8928
# Epoch 26/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.7019 - loss: 0.7782
# Epoch 26: val_f1_score improved from 0.58520 to 0.58618, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 26: val_loss improved from 0.87871 to 0.87457, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 162ms/step - f1_score: 0.7019 - loss: 0.7782 - val_f1_score: 0.5862 - val_loss: 0.8746
# Epoch 27/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7062 - loss: 0.7704
# Epoch 27: val_f1_score did not improve from 0.58618
#
# Epoch 27: val_loss did not improve from 0.87457
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 123s 162ms/step - f1_score: 0.7062 - loss: 0.7704 - val_f1_score: 0.5834 - val_loss: 0.8872
# Epoch 28/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7089 - loss: 0.7613
# Epoch 28: val_f1_score did not improve from 0.58618
#
# Epoch 28: val_loss did not improve from 0.87457
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 138s 158ms/step - f1_score: 0.7089 - loss: 0.7613 - val_f1_score: 0.5851 - val_loss: 0.8808
# Epoch 29/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - f1_score: 0.7095 - loss: 0.7602
# Epoch 29: val_f1_score did not improve from 0.58618
#
# Epoch 29: val_loss did not improve from 0.87457
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 123s 162ms/step - f1_score: 0.7095 - loss: 0.7602 - val_f1_score: 0.5737 - val_loss: 0.8975
# Epoch 30/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7110 - loss: 0.7559
# Epoch 30: val_f1_score did not improve from 0.58618
#
# Epoch 30: val_loss did not improve from 0.87457
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 139s 158ms/step - f1_score: 0.7110 - loss: 0.7559 - val_f1_score: 0.5844 - val_loss: 0.8770
# Epoch 31/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7157 - loss: 0.7522
# Epoch 31: val_f1_score improved from 0.58618 to 0.59779, saving model to drive/MyDrive/best_f1withsmote.keras
#
# Epoch 31: val_loss improved from 0.87457 to 0.86993, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 146s 163ms/step - f1_score: 0.7157 - loss: 0.7523 - val_f1_score: 0.5978 - val_loss: 0.8699
# Epoch 32/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7151 - loss: 0.7492
# Epoch 32: val_f1_score did not improve from 0.59779
#
# Epoch 32: val_loss improved from 0.86993 to 0.86667, saving model to drive/MyDrive/best_losswithsmote.keras
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 123s 163ms/step - f1_score: 0.7151 - loss: 0.7492 - val_f1_score: 0.5882 - val_loss: 0.8667
# Epoch 33/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7151 - loss: 0.7546
# Epoch 33: val_f1_score did not improve from 0.59779
#
# Epoch 33: val_loss did not improve from 0.86667
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 162ms/step - f1_score: 0.7151 - loss: 0.7546 - val_f1_score: 0.5945 - val_loss: 0.8727
# Epoch 34/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7152 - loss: 0.7508
# Epoch 34: val_f1_score did not improve from 0.59779
#
# Epoch 34: val_loss did not improve from 0.86667
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 139s 158ms/step - f1_score: 0.7152 - loss: 0.7508 - val_f1_score: 0.5888 - val_loss: 0.8810
# Epoch 35/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7183 - loss: 0.7441
# Epoch 35: val_f1_score did not improve from 0.59779
#
# Epoch 35: val_loss did not improve from 0.86667
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 146s 163ms/step - f1_score: 0.7183 - loss: 0.7441 - val_f1_score: 0.5943 - val_loss: 0.8716
# Epoch 36/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7220 - loss: 0.7374
# Epoch 36: val_f1_score did not improve from 0.59779
#
# Epoch 36: val_loss did not improve from 0.86667
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 138s 158ms/step - f1_score: 0.7220 - loss: 0.7375 - val_f1_score: 0.5880 - val_loss: 0.8843
# Epoch 37/50
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - f1_score: 0.7178 - loss: 0.7454
# Epoch 37: val_f1_score did not improve from 0.59779
#
# Epoch 37: val_loss did not improve from 0.86667
# 756/756 ━━━━━━━━━━━━━━━━━━━━ 142s 158ms/step - f1_score: 0.7178 - loss: 0.7454 - val_f1_score: 0.5948 - val_loss: 0.8848

# %%
pd.DataFrame(history.history).to_csv('drive/MyDrive/history.csv', index=False)

# %%
# индекс эпохи с max val_f1
best_epoch = np.argmax(history.history['val_f1_score'])

# Метрики лучшей эпохи
best_metrics = {
    'epoch': best_epoch + 1,
    'train_loss': history.history['loss'][best_epoch],
    'val_loss': history.history['val_loss'][best_epoch],
    'train_f1': history.history['f1_score'][best_epoch],
    'val_f1': history.history['val_f1_score'][best_epoch]
}

print(f"Лучшая эпоха: {best_epoch + 1}")
print(f"Train F1: {best_metrics['train_f1']:.4f}")
print(f"Train loss: {best_metrics['train_loss']:.4f}")
print(f"Validation F1: {best_metrics['val_f1']:.4f}")
print(f"Validation Loss: {best_metrics['val_loss']:.4f}")
# Out:
# Лучшая эпоха: 31
# Train F1: 0.7125
# Train loss: 0.7575
# Validation F1: 0.5978
# Validation Loss: 0.8699

# %%
# Получение предсказаний
y_pred = model.predict(X_val_scaled)
y_pred_classes = np.argmax(y_pred, axis=1)

# Преобразование для истинных меток
y_true_classes = np.argmax(y_val_onehot, axis=1)

# Создание confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Визуализация
plt.figure(figsize=(10, 8))
sns.heatmap(cm,
           annot=True,
           fmt='d',
           cmap='Blues',
           xticklabels=ohe_main.categories_[0],
           yticklabels=ohe_main.categories_[0])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 596/596 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step

# %%
# Генерация отчета
class_names = ohe_main.categories_[0] 
report = classification_report(
    y_true_classes,
    y_pred_classes,
    target_names=class_names,
    digits=4
)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    ECLIPSING     0.6421    0.5678    0.6027      5491
#     ERUPTIVE     0.4693    0.4795    0.4743       732
#    PULSATING     0.6774    0.8201    0.7419      8683
#     ROTATING     0.5903    0.4247    0.4940      3141
#  cataclysmic     0.7770    0.5268    0.6279      1025
#
#     accuracy                         0.6535     19072
#    macro avg     0.6312    0.5638    0.5882     19072
# weighted avg     0.6502    0.6535    0.6446     19072

# %%
plt.figure(figsize=(15, 6))

# График для Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue', linestyle='--')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red', linestyle='-')
plt.title('Loss Dynamics')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# График для F1 Macro
plt.subplot(1, 2, 2)
plt.plot(history.history['f1_score'], label='Train F1 Macro', color='green', linestyle='--')
plt.plot(history.history['val_f1_score'], label='Validation F1 Macro', color='orange', linestyle='-')
plt.title('F1 Macro Dynamics')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
